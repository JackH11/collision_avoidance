# %%
from nn.nn import build_model, build_uncertainty_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from nn.nn import build_model, build_uncertainty_model
#
# ModuleNotFoundError: No module named 'nn.nn'; 'nn' is not a package

# %%
build_uncertainty_model(10)
# Out:
# <Sequential name=sequential_2, built=True>
